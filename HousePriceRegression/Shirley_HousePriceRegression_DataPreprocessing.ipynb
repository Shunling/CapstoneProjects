# %% [markdown]
# # Capstone project 1: House prices advanced regression

# %%
#-----------------------------------------------------------------------------#
import pandas as pd
import numpy as np
import json

import matplotlib.pyplot as plt
import seaborn as sns
from IPython import display
from ipywidgets import interact, widgets
import matplotlib.cm as cm
import matplotlib.colors as colors

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Preprocessing with Dummy Table

# %%
df = pd.read_csv('./data/df_clean.csv',index_col='Id')
df['SoldTime'] = pd.to_datetime(df['SoldTime'])
df.head(2)
# Out:
#    MSZoning Street Alley LotShape LandContour Utilities LotConfig LandSlope  \
# Id
# 1        RL   Pave     0      Reg         Lvl    AllPub    Inside       Gtl
# 2        RL   Pave     0      Reg         Lvl    AllPub       FR2       Gtl
#
#    Neighborhood Condition1  ... OpenPorchSF EnclosedPorch 3SsnPorch  \
# Id                          ...
# 1       CollgCr       Norm  ...          61             0         0
# 2       Veenker      Feedr  ...           0             0         0
#
#    ScreenPorch PoolArea MiscVal MoSold YrSold SalePrice   SoldTime
# Id
# 1            0        0       0      2   2008    208500 2008-02-01
# 2            0        0       0      5   2007    181500 2007-05-01
#
# [2 rows x 81 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1460 entries, 1 to 1460
# Data columns (total 81 columns):
# MSZoning         1460 non-null object
# Street           1460 non-null object
# Alley            1460 non-null object
# LotShape         1460 non-null object
# LandContour      1460 non-null object
# Utilities        1460 non-null object
# LotConfig        1460 non-null object
# LandSlope        1460 non-null object
# Neighborhood     1460 non-null object
# Condition1       1460 non-null object
# Condition2       1460 non-null object
# BldgType         1460 non-null object
# HouseStyle       1460 non-null object
# RoofStyle        1460 non-null object
# RoofMatl         1460 non-null object
# Exterior1st      1460 non-null object
# Exterior2nd      1460 non-null object
# MasVnrType       1460 non-null object
# ExterQual        1460 non-null object
# ExterCond        1460 non-null object
# Foundation       1460 non-null object
# BsmtQual         1460 non-null object
# ...

# %%
i = 0
for col in df.columns:
    if df[col].dtypes == 'object':
        df[col] = df[col].astype('category')
        i += 1

df.MSSubClass = df.MSSubClass.astype('category')
i += 1

cat_cols = df.columns[:i]
num_cols = df.columns[i:]

# %%
y = df['SalePrice']
dummies = df[num_cols].drop('SalePrice',axis=1)

# %%
for col in cat_cols:
    dummy_col = pd.get_dummies(df[[col]], prefix_sep = '_')

    dummies = dummies.join(dummy_col, on='Id')

# %%
dummies.shape
# Out:
# (1460, 319)

# %%
dummies.columns
# Out:
# Index(['LotFrontage', 'LotArea', 'OverallQual', 'OverallCond', 'YearBuilt',
#        'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF',
#        ...
#        'MSSubClass_60', 'MSSubClass_70', 'MSSubClass_75', 'MSSubClass_80',
#        'MSSubClass_85', 'MSSubClass_90', 'MSSubClass_120', 'MSSubClass_160',
#        'MSSubClass_180', 'MSSubClass_190'],
#       dtype='object', length=319)

# %%
X_train, X_test, y_train, y_test = train_test_split(dummies, y, test_size=0.3, random_state=7)

# %%
X_train.head(2)
# Out:
#       LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# Id
# 681          50.0     8012            6            5         30            30
# 1452         78.0     9262            8            5          1             0
#
#       MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  ...  MSSubClass_60  \
# Id                                                   ...
# 681          0.0         543         119        261  ...              0
# 1452       194.0           0           0       1573  ...              0
#
#       MSSubClass_70  MSSubClass_75  MSSubClass_80  MSSubClass_85  \
# Id
# 681               0              0              0              0
# 1452              0              0              0              0
#
#       MSSubClass_90  MSSubClass_120  MSSubClass_160  MSSubClass_180  \
# Id
# 681               0               1               0               0
# 1452              0               0               0               0
#
#       MSSubClass_190
# Id
# ...

# %%
# Save all processed data into folder

X_train.to_csv('./dummy_data/X_train.csv')
X_test.to_csv('./dummy_data/X_test.csv')
y_train.to_csv('./dummy_data/y_train.csv')
y_test.to_csv('./dummy_data/y_test.csv')
# Out:
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#   """
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
